# %% [markdown]
# # Classification

# %% [markdown]
# ## Data import

# %%
import pandas as pd
import os
import numpy as np

# %%
traindata_url = 'https://bitbucket.org/hyuk125/lg_dic/raw/889649d1bc273bf53967cb621a370205715b803b/dataset_day1/mnist_train.csv'
testdata_url = 'https://bitbucket.org/hyuk125/lg_dic/raw/889649d1bc273bf53967cb621a370205715b803b/dataset_day1/mnist_test.csv'
train_data = pd.read_csv(traindata_url)
test_data = pd.read_csv(testdata_url)

# %%
X_train = train_data.values[:, 1:] 
y_train = train_data.values[:, 0]
X_test = test_data.values[:, 1:]
y_test = test_data.values[:, 0]

# %%
X = np.r_[X_train, X_test]
y = np.r_[y_train, y_test]

# %% [markdown]
# ## Classification 모델

# %% [markdown]
# ### Data 처리
# #### Training / test 분할

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ### Randomforest classification 모델 학습

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=50, max_leaf_nodes=16, n_jobs=-1) 
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=16, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=-1,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %% [markdown]
# ## Model Test

# %% [markdown]
# ## 정확도 판단

# %% [markdown]
# ### Confution matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
predict = model.predict(X_test)

# %%
matrix = confusion_matrix(y_test, predict)
matrix
# Out:
# array([[1662,    0,    5,    7,    1,    2,   16,    1,   40,    1],
#        [   0, 1929,    7,   20,    1,    0,    3,   10,    8,    1],
#        [  28,   76, 1442,   47,   22,    2,   65,   38,   38,   13],
#        [  30,   48,   59, 1469,    6,   14,   13,   28,   45,   45],
#        [  19,   13,    9,    5, 1297,    0,   51,   28,   10,  189],
#        [ 126,  107,   20,  319,   62,  720,   59,   29,   39,  104],
#        [  86,   47,   48,    8,   50,   11, 1461,   10,   19,    0],
#        [  22,   55,   65,    1,   36,    0,    1, 1598,   16,   70],
#        [  25,  133,   30,  101,   19,   15,   34,   10, 1248,   80],
#        [  19,   25,   19,   28,   77,    4,    9,  100,   31, 1441]])

# %% [markdown]
# ### Precision, recall

# %%
from sklearn.metrics import precision_score, recall_score

# %%
print(precision_score(y_test, predict, average=None))
print('average: ', precision_score(y_test, predict, average='weighted'))
# Out:
# [0.82399603 0.79284834 0.84624413 0.73266833 0.8255888  0.9375
#  0.85338785 0.86285097 0.83534137 0.74125514]
# average:  0.8238552273525143

# %%
print(recall_score(y_test, predict, average=None))
print('average: ', recall_score(y_test, predict, average='weighted'))
# Out:
# [0.95792507 0.97473471 0.81422925 0.83608423 0.80012338 0.45425868
#  0.83965517 0.85729614 0.73628319 0.8220194 ]
# average:  0.8152571428571429
